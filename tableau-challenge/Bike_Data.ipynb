# %%
# libaries 
import os
import glob
import pandas as pd
import numpy as np
import datetime

# %%
os.chdir("C:/Users/nikDev/Documents/UCI_BootCamp/UCI_HomeWork_Yeung/tableau-challenge/Resources")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "BikeData.csv", index=False, encoding='utf-8-sig')

# %%
bikeData = pd.read_csv("../Resources/BikeData.csv")
bikeData.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
bikeData.shape
# Out:
# (1095641, 15)

# %%
bikeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095641 entries, 0 to 1095640
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1095641 non-null  int64
#  1   starttime                1095641 non-null  object
#  2   stoptime                 1095641 non-null  object
#  3   start station id         1095641 non-null  int64
#  4   start station name       1095641 non-null  object
#  5   start station latitude   1095641 non-null  float64
#  6   start station longitude  1095641 non-null  float64
#  7   end station id           1095641 non-null  int64
#  8   end station name         1095641 non-null  object
#  9   end station latitude     1095641 non-null  float64
#  10  end station longitude    1095641 non-null  float64
#  11  bikeid                   1095641 non-null  int64
#  12  usertype                 1095641 non-null  object
# ...

# %%
bikeData.describe(include="all")
# Out:
#         tripduration                 starttime                  stoptime  \
# count   1.095641e+06                   1095641                   1095641
# unique           NaN                   1082181                   1082175
# top              NaN  2020-10-07 22:22:36.4330  2020-10-04 16:40:42.4810
# freq             NaN                         2                         2
# mean    9.698432e+02                       NaN                       NaN
# std     1.229917e+04                       NaN                       NaN
# min     6.100000e+01                       NaN                       NaN
# 25%     2.470000e+02                       NaN                       NaN
# 50%     3.910000e+02                       NaN                       NaN
# 75%     7.370000e+02                       NaN                       NaN
# max     3.261756e+06                       NaN                       NaN
#
#         start station id start station name  start station latitude  \
# ...

# %%
# check if there are any nulls
bikeData.isnull().values.any()
# Out:
# False

# %%
bikeData.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
bikeData['day'] =bikeData['starttime'].apply(lambda x: pd.Timestamp(x).strftime('%Y-%m-%d'))

# %%
bikeData.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
bikeData.shape
# Out:
# (1095641, 16)

# %%
bikeData.to_csv("../Resources/BikeData_addCols.csv", index=False)
